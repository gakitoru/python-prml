# %%
# %matplotlib inline 
import numpy as np
import math
import matplotlib.pyplot as plt
#from scipy.stats import norm

X = np.linspace(0, 1, 10)
T = [math.sin(2*math.pi*x) + np.random.normal(loc=0, scale=0.2) for x in X]

print(X)
print(T)
plt.scatter(X, T)

X_ref = np.linspace(0, 1, 1000)
T_ref = [math.sin(2*math.pi*x) for x in X_ref]

plt.plot(X_ref, T_ref, c='g')
plt.show()
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
# [-0.41171649405856264, 0.499863150071688, 1.09525395659006, 0.8196867353674987, 0.682675962392417, -0.3469774931449244, -0.5353997898954168, -0.9572173660982566, -0.694460270348107, 0.364411148645413]
